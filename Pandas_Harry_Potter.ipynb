# %% [markdown]
# # Pandas

# %%
#import pandas module
import pandas as pd
import numpy as np

# %% [markdown]
# **Creating a Dataframe**

# %%
# Creating by passing a dictionary {}
# Key is column name
# Value is a list 

students = pd.DataFrame({
    'name':['Harry Potter','Ron Weasley','Hermione Granger','Luna Lovegood','Susan Bones','Draco Malfoy','Neville Longbottom'],
    'house':['Gryffindor','Gryffindor','Gryffindor','Ravenclaw','Hufflepuff','Slytherin','Gryffindor'],
    'age': [11,11,10,11,12,12,11],
    'blood':['Half-Blood','Pure-Blood','Muggle-born','Pure-Blood','Half-Blood','Pure-Blood','Pure-Blood'],
    'grade':[89,86,100,95,78,60,98],
    'height':[4.6,4.11,4.3,4.4,4.2,4.9,4.8]
})

# %%
print(students)
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4         Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5        Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
# Creating dataframe by passing lists []
# one list represents one row 
# Columns argument to list column names

head_house = pd.DataFrame([
    ['Minerva McGonagall','Gryffindor','Transfiguration','F'],
    ['Severus Snape','Slytherin','Potions','M'],
    ['Pomona Spout','Hufflepuff','Herbology','F'],
    ['Filius Flitwik','Ravenclaw','Charms','M']],
    columns=['Name','House','Subject','Gender']
)

# %%
print(head_house)
# Out:
#                  Name       House          Subject Gender
# 0  Minerva McGonagall  Gryffindor  Transfiguration      F
# 1       Severus Snape   Slytherin          Potions      M
# 2        Pomona Spout  Hufflepuff        Herbology      F
# 3      Filius Flitwik   Ravenclaw           Charms      M

# %%
# Load a csv file
# https://www.kaggle.com/nehatiwari03/harry-potter-fanfiction-data
# The dataset was too large. Only extracted top 50 rows for this example
hp= pd.read_csv("hp_topfifty.csv")

# %%
hp.head(2)
# Out:
#    Unnamed: 0  Chapters  Favs  Follows    Published  Reviews Updated    Words  \
# 0           0         1   2.0      NaN   12/31/2019      1.0     NaN    6,840
# 1           1         1   1.0      NaN   12/31/2019      NaN     NaN   10,962
#
#      author                                   characters               genre  \
# 0   reviews    Sirius B., Remus L., James P., Regulus B.  Angst/Hurt/Comfort
# 1  JoyI9199  Harry P., Draco M., Narcissa M., Charlie W.         Angst/Drama
#
#   language rating                                         story_link  \
# 0  English      T  https://www.fanfiction.net/s/13466909/1/If-You...
# 1  English      M  https://www.fanfiction.net/s/13466894/1/Bloody...
#
#                                             synopsis                    title  \
# 0  Regulus and James aren't happy. They know they...  If You Change Your Mind
# 1  When a plot from the Founder's age is revealed...         Bloody Ballgowns
#
#   published_mmyy pairing
# ...

# %% [markdown]
# **Select Columns Rows of a DataFrame**

# %%
students
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4         Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5        Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
# This is a DataFrame
type(students)
# Out:
# pandas.core.frame.DataFrame

# %%
# Selecting one column of a dataframe
name_col = students.name

# %%
print(name_col)
# Out:
# 0          Harry Potter
# 1           Ron Weasley
# 2      Hermione Granger
# 3         Luna Lovegood
# 4           Susan Bones
# 5          Draco Malfoy
# 6    Neville Longbottom
# Name: name, dtype: object

# %%
# This is not a dataframe just a column
type(name_col)
# Out:
# pandas.core.series.Series

# %%
# Selecting more than one column of DataFrame
student_n_age = students[['name','age']]

# %%
print(student_n_age)
# Out:
#                  name  age
# 0        Harry Potter   11
# 1         Ron Weasley   11
# 2    Hermione Granger   10
# 3       Luna Lovegood   11
# 4         Susan Bones   12
# 5        Draco Malfoy   12
# 6  Neville Longbottom   11

# %%
# more than one column - Type is a DataFrame
type(student_n_age)
# Out:
# pandas.core.frame.DataFrame

# %%
# Select a row from dataframe
s4 = students.iloc[3]

# %%
# Starts at index 0, Luna is on Row 4 but index 3
s4
# Out:
# name      Luna Lovegood
# house         Ravenclaw
# age                  11
# blood        Pure-Blood
# grade                95
# height              4.4
# Name: 3, dtype: object

# %%
# series type
type(s4)
# Out:
# pandas.core.series.Series

# %%
# Select more than one row . Will not include the ending index ie 3 in this case
s_more = students.iloc[0:3]

# %%
s_more
# Out:
#                name       house  age        blood  grade  height
# 0      Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1       Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2  Hermione Granger  Gryffindor   10  Muggle-born    100    4.30

# %%
# Dataframe type
type(s_more)
# Out:
# pandas.core.frame.DataFrame

# %%
students.iloc[:3]
# Out:
#                name       house  age        blood  grade  height
# 0      Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1       Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2  Hermione Granger  Gryffindor   10  Muggle-born    100    4.30

# %%
students.iloc[3:]
# Out:
#                  name       house  age       blood  grade  height
# 3       Luna Lovegood   Ravenclaw   11  Pure-Blood     95     4.4
# 4         Susan Bones  Hufflepuff   12  Half-Blood     78     4.2
# 5        Draco Malfoy   Slytherin   12  Pure-Blood     60     4.9
# 6  Neville Longbottom  Gryffindor   11  Pure-Blood     98     4.8

# %%
students.iloc[-2:]
# Out:
#                  name       house  age       blood  grade  height
# 5        Draco Malfoy   Slytherin   12  Pure-Blood     60     4.9
# 6  Neville Longbottom  Gryffindor   11  Pure-Blood     98     4.8

# %%
students.iloc[:-2]
# Out:
#                name       house  age        blood  grade  height
# 0      Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1       Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2  Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3     Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4       Susan Bones  Hufflepuff   12   Half-Blood     78    4.20

# %%
students.iloc[-4:-1]
# Out:
#             name       house  age       blood  grade  height
# 3  Luna Lovegood   Ravenclaw   11  Pure-Blood     95     4.4
# 4    Susan Bones  Hufflepuff   12  Half-Blood     78     4.2
# 5   Draco Malfoy   Slytherin   12  Pure-Blood     60     4.9

# %%
# select rows that match a condition
gryffindor = students[students.house == 'Gryffindor']

# %%
print(gryffindor)
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 6  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
not_gryffindor = students[students.house != 'Gryffindor']

# %%
not_gryffindor
# Out:
#             name       house  age       blood  grade  height
# 3  Luna Lovegood   Ravenclaw   11  Pure-Blood     95     4.4
# 4    Susan Bones  Hufflepuff   12  Half-Blood     78     4.2
# 5   Draco Malfoy   Slytherin   12  Pure-Blood     60     4.9

# %%
# more than one condition using & 
y_gryffindor = students[(students.house == 'Gryffindor') & (students.blood == 'Pure-Blood')]

# %%
y_gryffindor
# Out:
#                  name       house  age       blood  grade  height
# 1         Ron Weasley  Gryffindor   11  Pure-Blood     86    4.11
# 6  Neville Longbottom  Gryffindor   11  Pure-Blood     98    4.80

# %%
# more than one condition using | pipe - it means or
y_g = students[(students.house == 'Gryffindor') | (students.age < 12)]

# %%
y_g
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 6  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
# Select rows using isin . Returns the matching rows
students[students.blood.isin(['Pure-Blood','Half-Blood'])]
# Out:
#                  name       house  age       blood  grade  height
# 0        Harry Potter  Gryffindor   11  Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11  Pure-Blood     86    4.11
# 3       Luna Lovegood   Ravenclaw   11  Pure-Blood     95    4.40
# 4         Susan Bones  Hufflepuff   12  Half-Blood     78    4.20
# 5        Draco Malfoy   Slytherin   12  Pure-Blood     60    4.90
# 6  Neville Longbottom  Gryffindor   11  Pure-Blood     98    4.80

# %% [markdown]
# **Reset Index**

# %%
# the index is not in order as this is just a selected rows
y_g
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 6  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
# This will create a new index but will keep the new index. ANd this does not change the original dataframe index
y_g.reset_index()
# Out:
#    index                name       house  age        blood  grade  height
# 0      0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1      1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2      2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3      3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4      6  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
# index dint change
y_g
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 6  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
# This will drop the index column that has old index number. But will not change the original
y_g.reset_index(drop=True)
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
y_g
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 6  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %%
# This will change the index in the original dataframe
y_g.reset_index(drop=True,inplace=True)

# %%
y_g
# Out:
#                  name       house  age        blood  grade  height
# 0        Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1         Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2    Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3       Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4  Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80

# %% [markdown]
# **Adding/Renaming Columns/rows  to DataFrame**

# %%
# Adding rows to end of dataframe
d1  = [{'name': 'Cedric Diggory', 'house':'Hufflepuff','age':16,'blood': 'Half-Blood','grade':87,'height': 5.1}]

s1 = students.append(d1,ignore_index=True,sort=False)

d2  = [{'name': 'Cho Chang', 'house':'Ravenclaw','age':12,'blood': 'Pure-Blood','grade':89,'height': 4.3}]

s2 = s1.append(d2,ignore_index=True,sort=False)

d3  = [{'name': 'Hannah Abbott', 'house':'Hufflepuff','age':12,'blood': 'Muggle-born','grade':92,'height': 4.3}]

s3 = s2.append(d3,ignore_index=True,sort=False)

d4  = [{'name': 'Padma Patil', 'house':'Ravenclaw','age':11,'blood': 'Pure-Blood','grade':79,'height': 4.2}]

s4=s3.append(d4,ignore_index=True,sort=False)

d5  = [{'name': 'Gregory Goyle', 'house':'Slytherin','age':12,'blood': 'Pure-Blood','grade':65,'height': 4.9}]

d6  = [{'name': 'Vincent Crabbe', 'house':'Slytherin','age':12,'blood': 'Half-Blood','grade':69,'height': 4.7}]

s5=s4.append(d5,ignore_index=True,sort=False)
students = s5.append(d6,ignore_index=True,sort=False)

students
# Out:
#                   name       house  age        blood  grade  height
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70

# %%
head_house
# Out:
#                  Name       House          Subject Gender
# 0  Minerva McGonagall  Gryffindor  Transfiguration      F
# 1       Severus Snape   Slytherin          Potions      M
# 2        Pomona Spout  Hufflepuff        Herbology      F
# 3      Filius Flitwik   Ravenclaw           Charms      M

# %%
# adding a column to the dataframe
head_house['animal'] = [ 'Lion','Snake','Badger','Eagle']

# %%
head_house
# Out:
#                  Name       House          Subject Gender  animal
# 0  Minerva McGonagall  Gryffindor  Transfiguration      F    Lion
# 1       Severus Snape   Slytherin          Potions      M   Snake
# 2        Pomona Spout  Hufflepuff        Herbology      F  Badger
# 3      Filius Flitwik   Ravenclaw           Charms      M   Eagle

# %%
# Rename column by passing dictionary in orignal datafrome - inplace true 
head_house.rename(columns = {'Name':'Head_Name',
                             'animal':'animal'},inplace = True)

# %%
# adding a column with same details for all rows
head_house['HogwartsHouse'] = 'Yes'

# %%
head_house
# Out:
#             Head_Name       House          Subject Gender  animal  \
# 0  Minerva McGonagall  Gryffindor  Transfiguration      F    Lion
# 1       Severus Snape   Slytherin          Potions      M   Snake
# 2        Pomona Spout  Hufflepuff        Herbology      F  Badger
# 3      Filius Flitwik   Ravenclaw           Charms      M   Eagle
#
#   HogwartsHouse
# 0           Yes
# 1           Yes
# 2           Yes
# 3           Yes

# %%
students
# Out:
#                   name       house  age        blood  grade  height
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70

# %%
#renaming all columns 
students.columns =['Name','House','Age','Blood_Type','Grade','Height']

# %%
# Adding columns by performing some function on exisiting column
students['broom_weight'] = students['Height']*2.892 + students['Age']

# %%
students
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
#
# ...

# %% [markdown]
# **Lambda Function Column and Row in DataFrame**

# %%
# Split name for students into first and last name
First_name = lambda x: x.split()[0]
students['First_name'] = students.Name.apply(First_name)

# %%
students
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
#
# ...

# %%
# Split name for students into first and last name
Last_name = lambda x: x.split()[-1]
students['Last_name'] = students.Name.apply(Last_name)

# %%
students['Blood'] = students.Blood_Type.apply(
    lambda x: x.split('-')[0]
    )

# %%
students
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
#
# ...

# %%
students['Blood'] = students.Blood_Type.apply(
    lambda x: x.split('-')[-1]
    )

# %%
students
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
#
# ...

# %%
# Applying Lambda to a row
# Checking if students is tall to fly
students['can_play'] = students.apply(lambda row:
     'yes'
     if row['Height'] >= 4.5
     else 'No',
     axis=1
)

# %%
students
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
#
# ...

# %%
# if house is gryffindor then brave 
students['brave'] = students.House.apply(lambda x: 'Yes' if x =='Gryffindor' else 'No')

# %%
students
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
#
# ...

# %%
# Adding Safe in First_name if Pure-Blood
students['pure_safe'] = students.apply(lambda row : 'Safe ' + row['First_name']
                                       if row['Blood_Type']=='Pure-Blood'
                                      else 'Not_safe ' + row['First_name'],axis=1)

# %%
students
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
#
# ...

# %%
# removing extra colums
students.drop(['First_name', 'Last_name','Blood','brave','pure_safe'], axis = 1)
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
#
# ...

# %% [markdown]
# **Columns calculations**

# %%
# Average
# Getting the average height of students
students.Height.mean()
# Out:
# 4.523846153846154

# %%
# median
# Median grade
students.Grade.median()
# Out:
# 87.0

# %%
# Unique houses
students.House.unique()
# Out:
# array(['Gryffindor', 'Ravenclaw', 'Hufflepuff', 'Slytherin'], dtype=object)

# %%
# number of unique blood type
students.Blood_Type.nunique()
# Out:
# 3

# %%
# Max
students.broom_weight.max()
# Out:
# 30.7492

# %%
# Min
students.broom_weight.min()
# Out:
# 22.4356

# %%
#Standard Deviation
students.Height.std()
# Out:
# 0.3259227531573103

# %%
#Count
students.Name.count()
# Out:
# 13

# %%
# group by 
students.groupby('House').Height.mean()
# Out:
# House
# Gryffindor    4.452500
# Hufflepuff    4.533333
# Ravenclaw     4.300000
# Slytherin     4.833333
# Name: Height, dtype: float64

# %%
students.groupby('House').Grade.min()
# Out:
# House
# Gryffindor    86
# Hufflepuff    78
# Ravenclaw     79
# Slytherin     60
# Name: Grade, dtype: int64

# %%
goods = students.groupby('House').Grade.max()

# %%
print(goods)
# Out:
# House
# Gryffindor    100
# Hufflepuff     92
# Ravenclaw      95
# Slytherin      69
# Name: Grade, dtype: int64

# %%
# This creates a series
type(goods)
# Out:
# pandas.core.series.Series

# %%
# to create a dataframe add reset.index() at the end

# %%
goods = students.groupby('House').Grade.max().reset_index()

# %%
goods
# Out:
#         House  Grade
# 0  Gryffindor    100
# 1  Hufflepuff     92
# 2   Ravenclaw     95
# 3   Slytherin     69

# %%
type(goods)
# Out:
# pandas.core.frame.DataFrame

# %%
# Applying lambda to get percentile of students with broom weight in 25 percentile
broom_25 = students.groupby('House').broom_weight.apply(lambda x: np.percentile(x,25)).reset_index()
print(broom_25)
# Out:
#         House  broom_weight
# 0  Gryffindor      22.77349
# 1  Hufflepuff      24.29100
# 2   Ravenclaw      23.43560
# 3   Slytherin      25.88160

# %%
h_p_counts = students.groupby(['House','Blood_Type'])['Name'].count().reset_index()

# %%
h_p_counts
# Out:
#         House   Blood_Type  Name
# 0  Gryffindor   Half-Blood     1
# 1  Gryffindor  Muggle-born     1
# 2  Gryffindor   Pure-Blood     2
# 3  Hufflepuff   Half-Blood     2
# 4  Hufflepuff  Muggle-born     1
# 5   Ravenclaw   Pure-Blood     3
# 6   Slytherin   Half-Blood     1
# 7   Slytherin   Pure-Blood     2

# %%
pivot = h_p_counts.pivot(
  columns = 'Blood_Type',
  index = 'House',
  values = 'Name'
).reset_index()

# %%
pivot
# Out:
# Blood_Type       House  Half-Blood  Muggle-born  Pure-Blood
# 0           Gryffindor         1.0          1.0         2.0
# 1           Hufflepuff         2.0          1.0         NaN
# 2            Ravenclaw         NaN          NaN         3.0
# 3            Slytherin         1.0          NaN         2.0

# %% [markdown]
# **Line Graphs using Matplotlib**

# %%
from matplotlib import pyplot as plt

# %%
students.sort_values(by=['Age'])
# Out:
#                   Name       House  Age   Blood_Type  Grade  Height  \
# 2     Hermione Granger  Gryffindor   10  Muggle-born    100    4.30
# 0         Harry Potter  Gryffindor   11   Half-Blood     89    4.60
# 1          Ron Weasley  Gryffindor   11   Pure-Blood     86    4.11
# 3        Luna Lovegood   Ravenclaw   11   Pure-Blood     95    4.40
# 6   Neville Longbottom  Gryffindor   11   Pure-Blood     98    4.80
# 10         Padma Patil   Ravenclaw   11   Pure-Blood     79    4.20
# 4          Susan Bones  Hufflepuff   12   Half-Blood     78    4.20
# 5         Draco Malfoy   Slytherin   12   Pure-Blood     60    4.90
# 8            Cho Chang   Ravenclaw   12   Pure-Blood     89    4.30
# 9        Hannah Abbott  Hufflepuff   12  Muggle-born     92    4.30
# 11       Gregory Goyle   Slytherin   12   Pure-Blood     65    4.90
# 12      Vincent Crabbe   Slytherin   12   Half-Blood     69    4.70
# 7       Cedric Diggory  Hufflepuff   16   Half-Blood     87    5.10
#
# ...

# %%
# age and grade plot
students.plot('Age', 'Height',color = 'blue',linestyle = ':',marker = '*')
plt.xlabel('Age')
plt.ylabel('Height')
plt.title("Weird wizard plot not meant for muggles,LOL")
plt.show()

# %%
plt.subplot(2,3,4)
students.plot('Age', 'Grade',color='purple',kind='scatter')
plt.xlabel('Age')
plt.ylabel('grade')
plt.title("less strange,LOL")
plt.show()

# %% [markdown]
# **Apply Function for Columns modification**

# %% [markdown]
# Upper Case or Lower Case
# from string import lower
# from string import upper

# %% [markdown]
#  Capitalize all in a column
# head_house['HogwartsHouse'] = head_house.HogwartsHouse.apply(upper)
